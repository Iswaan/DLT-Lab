# %% [markdown]
# 1) Import the necessray libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %% [markdown]
# 2) For the tutorial, lets experiment with random data

# %%
# Generate random input data (features)
num_samples = 1000
num_features = 10
num_classes = 2
X = np.random.rand(num_samples, num_features)

# %%
# Generate random output labels (classes)
y = np.random.randint(0, num_classes, size=num_samples)

# %%
# Split the data into training and testing sets
split_ratio = 0.8
split_index = int(num_samples * split_ratio)

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %% [markdown]
# 3) Define the model

# %%
# Build the neural network model using Sequential API
model = Sequential([
    Input(shape=(num_features,),name='input'),
    Dense(6, activation='relu',name='d1'),  # Hidden layer with 6 neurons
    Dense(2, activation='softmax')  # Output layer with num_classes neurons and softmax activation for classification
])

# %%
# Display a summary of the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  d1 (Dense)                  (None, 6)                 66
#
#  dense (Dense)               (None, 2)                 14
#
# =================================================================
# Total params: 80 (320.00 Byte)
# Trainable params: 80 (320.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 4) Compile the model

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 5) Fit/train the model

# %%
# Train the model using the training data
epochs = 50
batch_size = 32
h= model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 19ms/step - loss: 0.7041 - accuracy: 0.5042 - val_loss: 0.7042 - val_accuracy: 0.4750
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.5222 - val_loss: 0.7046 - val_accuracy: 0.4625
# Epoch 3/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6882 - accuracy: 0.5458 - val_loss: 0.7065 - val_accuracy: 0.5000
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6864 - accuracy: 0.5639 - val_loss: 0.7056 - val_accuracy: 0.5000
# Epoch 5/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.5653 - val_loss: 0.7051 - val_accuracy: 0.5000
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6850 - accuracy: 0.5542 - val_loss: 0.7056 - val_accuracy: 0.5250
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6840 - accuracy: 0.5528 - val_loss: 0.7046 - val_accuracy: 0.5250
# Epoch 8/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.5639 - val_loss: 0.7053 - val_accuracy: 0.5000
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6827 - accuracy: 0.5569 - val_loss: 0.7029 - val_accuracy: 0.5125
# Epoch 10/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6819 - accuracy: 0.5611 - val_loss: 0.7022 - val_accuracy: 0.5125
# Epoch 11/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6817 - accuracy: 0.5681 - val_loss: 0.7035 - val_accuracy: 0.5000
# Epoch 12/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6808 - accuracy: 0.5694 - val_loss: 0.7028 - val_accuracy: 0.5000
# Epoch 13/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6805 - accuracy: 0.5694 - val_loss: 0.7029 - val_accuracy: 0.4875
# Epoch 14/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6800 - accuracy: 0.5681 - val_loss: 0.7011 - val_accuracy: 0.4875
# Epoch 15/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6798 - accuracy: 0.5653 - val_loss: 0.7011 - val_accuracy: 0.4875
# Epoch 16/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6795 - accuracy: 0.5694 - val_loss: 0.7021 - val_accuracy: 0.4750
# Epoch 17/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6790 - accuracy: 0.5694 - val_loss: 0.6999 - val_accuracy: 0.4875
# Epoch 18/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6787 - accuracy: 0.5722 - val_loss: 0.7006 - val_accuracy: 0.4875
# Epoch 19/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6782 - accuracy: 0.5736 - val_loss: 0.7004 - val_accuracy: 0.4750
# Epoch 20/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6779 - accuracy: 0.5722 - val_loss: 0.7004 - val_accuracy: 0.4750
# Epoch 21/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6775 - accuracy: 0.5736 - val_loss: 0.6999 - val_accuracy: 0.4750
# Epoch 22/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6774 - accuracy: 0.5722 - val_loss: 0.7005 - val_accuracy: 0.4750
# Epoch 23/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6770 - accuracy: 0.5708 - val_loss: 0.7004 - val_accuracy: 0.4750
# Epoch 24/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.5722 - val_loss: 0.6997 - val_accuracy: 0.4750
# Epoch 25/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6765 - accuracy: 0.5708 - val_loss: 0.6995 - val_accuracy: 0.4750
# Epoch 26/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6762 - accuracy: 0.5736 - val_loss: 0.7000 - val_accuracy: 0.4750
# Epoch 27/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6760 - accuracy: 0.5694 - val_loss: 0.7010 - val_accuracy: 0.4875
# Epoch 28/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6758 - accuracy: 0.5681 - val_loss: 0.6995 - val_accuracy: 0.4750
# Epoch 29/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6753 - accuracy: 0.5681 - val_loss: 0.7004 - val_accuracy: 0.4875
# Epoch 30/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6751 - accuracy: 0.5694 - val_loss: 0.7007 - val_accuracy: 0.4875
# Epoch 31/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.5722 - val_loss: 0.6995 - val_accuracy: 0.4750
# Epoch 32/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6746 - accuracy: 0.5736 - val_loss: 0.7006 - val_accuracy: 0.4875
# Epoch 33/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6746 - accuracy: 0.5806 - val_loss: 0.7017 - val_accuracy: 0.5000
# Epoch 34/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6741 - accuracy: 0.5792 - val_loss: 0.7006 - val_accuracy: 0.4875
# Epoch 35/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6748 - accuracy: 0.5778 - val_loss: 0.6987 - val_accuracy: 0.4875
# Epoch 36/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6736 - accuracy: 0.5778 - val_loss: 0.7012 - val_accuracy: 0.5000
# Epoch 37/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6737 - accuracy: 0.5736 - val_loss: 0.6998 - val_accuracy: 0.4875
# Epoch 38/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6736 - accuracy: 0.5792 - val_loss: 0.7023 - val_accuracy: 0.5000
# Epoch 39/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6734 - accuracy: 0.5764 - val_loss: 0.7011 - val_accuracy: 0.5000
# Epoch 40/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6727 - accuracy: 0.5806 - val_loss: 0.7011 - val_accuracy: 0.5000
# Epoch 41/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6725 - accuracy: 0.5806 - val_loss: 0.7006 - val_accuracy: 0.5000
# Epoch 42/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6726 - accuracy: 0.5806 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 43/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6721 - accuracy: 0.5806 - val_loss: 0.7016 - val_accuracy: 0.5000
# Epoch 44/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6723 - accuracy: 0.5806 - val_loss: 0.7030 - val_accuracy: 0.5000
# Epoch 45/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6715 - accuracy: 0.5819 - val_loss: 0.7004 - val_accuracy: 0.4875
# Epoch 46/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6715 - accuracy: 0.5806 - val_loss: 0.6999 - val_accuracy: 0.4625
# Epoch 47/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6711 - accuracy: 0.5861 - val_loss: 0.7019 - val_accuracy: 0.4875
# Epoch 48/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6712 - accuracy: 0.5861 - val_loss: 0.7023 - val_accuracy: 0.4875
# Epoch 49/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6709 - accuracy: 0.5861 - val_loss: 0.7026 - val_accuracy: 0.4875
# Epoch 50/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6707 - accuracy: 0.5833 - val_loss: 0.7020 - val_accuracy: 0.5000

# %% [markdown]
# 6) Evaluate/test the model

# %%
# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test, y_test, batch_size=batch_size)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7303 - accuracy: 0.4250
# Test Loss: 0.730326771736145
# Test Accuracy: 0.42500001192092896
